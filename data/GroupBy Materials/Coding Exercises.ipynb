# %% [markdown]
# # Coding Exercises
# > 編碼練習

# %% [markdown]
# ### Welcome to the instructed and interactive Coding Exercises!
# > 歡迎來到指導和互動的編碼練習！

# %% [markdown]
# Now, you will have the opportunity to further analyze our Titanic and Olympic Medals datasets on your own. <br>
# There are __three different levels of difficulty__, starting from the gentle Beginner Level to the more tricky Expert Level.<br>
# __Follow the instructions__ and insert your code! You are either requested to
# - Complete the Code and __Fill in the gaps__. Gaps are marked with "__---__" and are __placeholders__ for your code fragment. (Beginner Level)
# - Write Code completely __on your own__ (Expert Level)
#
# > 現在，您將有機會自己進一步分析我們的泰坦尼克號和奧運獎牌數據集。
# > 有三種不同的難度級別，從溫和的初級水平到更棘手的專家水平。
# > 按照說明操作並插入代碼！ 你要么被要求
# >
# > - 完成準則並填補空白。 間隙標有“---”，是代碼片段的佔位符。 （初級水平）
# > - 完全自己編寫代碼（專家級別）

# %% [markdown]
# In some exercises, you will find questions that can only be answered, if your code is correct and returns the right output! The correct answer is provided below your coding cell. There you can check whether your code is correct.
# > 在某些練習中，如果您的代碼正確並返回正確的輸出，您將找到只能回答的問題！ 您的編碼單元下方提供了正確的答案。 在那裡，您可以檢查您的代碼是否正確。

# %% [markdown]
# If you need some further help or if you want to check your code, you can also watch the __solutions videos__ or check the __solutions notebook__.
# > 如果您需要一些進一步的幫助，或者如果您想檢查代碼，您還可以觀看解決方案視頻或查看解決方案筆記本。

# %% [markdown]
# ### Have Fun!

# %% [markdown]
# ------------------------------------------------------------------------------

# %% [markdown]
# ## Beginner Level

# %% [markdown]
# First of all, __import pandas__ and use the standard abbreviation __pd__. <br>
# __Fill in the gaps!__

# %%
# import --- as pd #hint: pandas might be the correct placeholder!
import pandas as pd #hint: pandas might be the correct placeholder!

# %% [markdown]
# Next, __import__ the csv-file __titanic.csv__ with __pd.read_csv()__ and save the DataFrame in the variable __titanic__. <br>
# __Fill in the gaps!__

# %%
# titanic = pd.---("---")
titanic = pd.read_csv("titanic.csv")

# %% [markdown]
# Let´s inspect the __first 10__ rows with the method __head()__.<br>
# __Fill in the gaps!__
# >  inspect (vt.)(vi.) 檢查；審查；檢閱；視察

# %%
# titanic.head(---)
titanic.head(n = 10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
# 5         0       3    male   NaN      0      0   8.4583        Q  NaN
# 6         0       1    male  54.0      0      0  51.8625        S    E
# 7         0       3    male   2.0      3      1  21.0750        S  NaN
# 8         1       3  female  27.0      0      2  11.1333        S  NaN
# 9         1       2  female  14.0      1      0  30.0708        C  NaN

# %% [markdown]
# Now, select the __fare column__ and save it in the __variable fare__. <br>
# __Fill in the gaps!__

# %%
# fare = titanic.---
fare = titanic.fare

# %% [markdown]
# Inspect the __first 7 elements__ of fare with the __head()__ method.<br>
# __Fill in the gaps!__

# %%
# fare.---(---)
fare.head(n = 7)
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# 5     8.4583
# 6    51.8625
# Name: fare, dtype: float64

# %% [markdown]
# __Sort__ fare with the __sort_values()__ method from __high to low__.<br>
# __Fill in the gaps!__

# %%
# fare.sort_---(ascending = ---)
fare.sort_values(ascending = False)
# Out:
# 679    512.3292
# 258    512.3292
# 737    512.3292
# 341    263.0000
# 438    263.0000
# 88     263.0000
# 27     263.0000
# 311    262.3750
# 742    262.3750
# 299    247.5208
# 118    247.5208
# 716    227.5250
# 557    227.5250
# 380    227.5250
# 700    227.5250
# 527    221.7792
# 377    211.5000
# 689    211.3375
# 730    211.3375
# 779    211.3375
# 318    164.8667
# 856    164.8667
# 268    153.4625
# 332    153.4625
# 609    153.4625
# 297    151.5500
# 305    151.5500
# 498    151.5500
# 708    151.5500
# 31     146.5208
#          ...
# 611      7.0500
# 477      7.0458
# 804      6.9750
# 129      6.9750
# 825      6.9500
# 411      6.8583
# 143      6.7500
# 654      6.7500
# 202      6.4958
# 371      6.4958
# 818      6.4500
# 843      6.4375
# 326      6.2375
# 872      5.0000
# 378      4.0125
# 815      0.0000
# 822      0.0000
# 481      0.0000
# 806      0.0000
# 179      0.0000
# 732      0.0000
# 466      0.0000
# 263      0.0000
# 674      0.0000
# 413      0.0000
# 277      0.0000
# 633      0.0000
# 302      0.0000
# 597      0.0000
# 271      0.0000
# Name: fare, Length: 891, dtype: float64

# %% [markdown]
# Now, let´s __visualize__ fare with a __histogramm__ to get the __frequency distribution__ of all fares.<br>
# But first of all, we need to __import matplolib.pyplot__ with the standard abbreviation __plt__.<br><br>
# __Fill in the gaps!__

# %%
# import matplotlib.--- as ---
# plt.style.use("seaborn")
# 
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %% [markdown]
# Next, we create a plot with the __plot()__ method and pass the argument __"hist"__ to the parameter __kind__. <br>
# __Figsize__ should be __(12,8)__. The __fontsize__ for the __axis labels__ shall be __13__. Insert the title __Titanic Ticket Price (Frequency Distribution)__.<br><br>
#
# __Fill in the gaps!__

# %%
# fare.---(kind = "---", bins = 100, figsize = (---,8), fontsize = 13)
# plt.xlabel("Ticket Price", fontsize = ---)
# plt.ylabel("Frequency", fontsize = ---)
# plt.title(---, fontsize = 15)
# plt.---()
# 
fare.plot(kind = "hist", bins = 100, figsize = (12,8), fontsize = 13)
plt.xlabel("Ticket Price", fontsize = 13)
plt.ylabel("Frequency", fontsize = 13)
plt.title(label = "Titanic Ticket Price (Frequency Distribution)", fontsize = 15)
plt.show()

# %% [markdown]
# ---
# 可以看到票價最多大約是在比0高一點點的價格
# 有些票很貴，最高的還高過500元。

# %% [markdown]
# Now, we want to calculate the __average/mean passenger age__ for all three __passenger classes__. <br>
# Therefore, we need to __split titanic__ by the key __pclass__ with the __groupby()__ method and apply the __mean()__ method on the __age column__.<br><br>
# __Fill in the gaps!__<br><br>
# What was the average age in the 3rd class?

# %%
# titanic.groupby(---).age.---
titanic.groupby("pclass").age.mean()
# Out:
# pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: age, dtype: float64

# %% [markdown]
# The average passenger age in the __3rd class__ was ... __25.14__ years old!

# %% [markdown]
# ## Well done!

# %% [markdown]
# ------------------------------------------------------------------------

# %% [markdown]
# ## Intermediate Level

# %%
import pandas as pd

# %% [markdown]
# Let´s __import__ the csv-file __summer.csv__ and store the DataFrame in the __variable summer__.

# %%
summer = pd.read_csv("summer.csv")

# %% [markdown]
# Inspect the __first 5 rows__.

# %%
summer.head(n = 5)
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %% [markdown]
# Get some __meta information__ on the summer DataFrame with the __info()__ method.

# %%
# summer.describe() #回傳數值欄位的統計量
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
# Year          31165 non-null int64
# City          31165 non-null object
# Sport         31165 non-null object
# Discipline    31165 non-null object
# Athlete       31165 non-null object
# Country       31161 non-null object
# Gender        31165 non-null object
# Event         31165 non-null object
# Medal         31165 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %% [markdown]
# In total we have... __31.165 rows__ and... __9 columns__.

# %% [markdown]
# As we are only interested in the __columns "Year", "Sport", "Athlete", "Country", "Gender" and "Medal"__, we __slice__ our DataFrame summer with the __loc operator__ and __overwrite our variable summer__.<br><br>
# __Fill in the gaps!__

# %%
# summer = summer.loc[---, ---]
summer = summer.loc[:, ["Year", "Sport", "Athlete", "Country", "Gender", "Medal"]]

# %% [markdown]
# Let´s again __inspect__ summer with the __head()__ method. Now, we have only __6 columns__, right?

# %%
summer.head()
# Out:
#    Year     Sport             Athlete Country Gender   Medal
# 0  1896  Aquatics       HAJOS, Alfred     HUN    Men    Gold
# 1  1896  Aquatics    HERSCHMANN, Otto     AUT    Men  Silver
# 2  1896  Aquatics   DRIVAS, Dimitrios     GRE    Men  Bronze
# 3  1896  Aquatics  MALOKINIS, Ioannis     GRE    Men    Gold
# 4  1896  Aquatics  CHASAPIS, Spiridon     GRE    Men  Silver

# %% [markdown]
# Lets´get some more information on the __Athlete Column__ with the __describe()__ method. <br>
# Who is the __most successful Athlete__ of all times and __how many medals__ has she/he won?

# %%
summer.Athlete
# Out:
# 0                            HAJOS, Alfred
# 1                         HERSCHMANN, Otto
# 2                        DRIVAS, Dimitrios
# 3                       MALOKINIS, Ioannis
# 4                       CHASAPIS, Spiridon
# 5                    CHOROPHAS, Efstathios
# 6                            HAJOS, Alfred
# 7                         ANDREOU, Joannis
# 8                    CHOROPHAS, Efstathios
# 9                            NEUMANN, Paul
# 10                       PEPANOS, Antonios
# 11                           LANE, Francis
# 12                        SZOKOLYI, Alajos
# 13                           BURKE, Thomas
# 14                          HOFMANN, Fritz
# 15                          CURTIS, Thomas
# 16                      GOULDING, Grantley
# 17                       LERMUSIAUX, Albin
# 18                            FLACK, Edwin
# 19                           BLAKE, Arthur
# 20                         GMELIN, Charles
# 21                           BURKE, Thomas
# 22                        JAMISON, Herbert
# 23                      GOLEMIS, Dimitrios
# 24                            FLACK, Edwin
# 25                            DANI, Nandor
# 26                        VERSIS, Sotirios
# 27                         GARRETT, Robert
# 28             PARASKEVOPOULOS, Panagiotis
# 29                           CLARK, Ellery
#                        ...
# 31135                     GAZYUMOV, Khetag
# 31136                  GOGSHELIDZE, George
# 31137                  LOPEZ NUNEZ, Mijain
# 31138                          NABI, Heiki
# 31139                         EUREN, Johan
# 31140                        KAYAALP, Riza
# 31141    SORYAN REIHANPOUR, Hamid Mohammad
# 31142                    BAYRAMOV, Rovshan
# 31143                         MODOS, Peter
# 31144                    SEMENOV, Mingiyan
# 31145                   NOROOZI, Omid Haji
# 31146                       LASHKHI, Revaz
# 31147                  KURAMAGOMEDOV, Zaur
# 31148                   MATSUMOTO, Ryutaro
# 31149                        KIM, Hyeonwoo
# 31150                       LORINCZ, Tamas
# 31151                       GUENOT, Steeve
# 31152                  TSKHADAIA, Manuchar
# 31153                        VLASOV, Roman
# 31154                   JULFALAKYAN, Arsen
# 31155                        AHMADOV, Emin
# 31156                 KAZAKEVIC, Aleksandr
# 31157                        KHUGAEV, Alan
# 31158         EBRAHIM, Karam Mohamed Gaber
# 31159                      GAJIYEV, Danyal
# 31160                   JANIKOWSKI, Damian
# 31161            REZAEI, Ghasem Gholamreza
# 31162                       TOTROV, Rustam
# 31163                    ALEKSANYAN, Artur
# 31164                       LIDBERG, Jimmy
# Name: Athlete, Length: 31165, dtype: object

# %%
summer.Athlete.describe()
# Out:
# count               31165
# unique              22762
# top       PHELPS, Michael
# freq                   22
# Name: Athlete, dtype: object

# %% [markdown]
# ---
# 上面方法就不用先GroupBy("Athlete")，再計數~
# 簡單地對該欄位做describe()，就可以很快找出出現頻率最高的類別。

# %%
# 另一種依樣可以找出，得最多獎牌的人的方法。
summer.groupby("Athlete").Medal.count().sort_values(ascending = False).head()
# Out:
# Athlete
# PHELPS, Michael         22
# LATYNINA, Larisa        18
# ANDRIANOV, Nikolay      15
# MANGIAROTTI, Edoardo    13
# SHAKHLIN, Boris         13
# Name: Medal, dtype: int64

# %% [markdown]
# ... it´s __Michael Phelps__ with ... __22 medals__

# %% [markdown]
# Now, we want to determine for __each country__: The __Year/Edition__ when the __very first Medal__ was awarded to an Athlete from this Country. For example 1896 for USA.<br><br>
# Therefore, __split__ the summer DataFrame __by Country__ and determine the __minimum value in the Year Column__ for each group/Country. Then, __sort__ the result in a __descending order__, starting with all countries that won the very first Medal in 2012. <br><br>
# __How many__ countries had their Medal debut in __2012__?
# > 現在，我們想確定每個國家：年度/版本，這是第一枚獎章頒發給該國的一名運動員。 例如美國的1896年。
# >
# > 因此，按國家/地區拆分夏季DataFrame，並確定每個組/國家/地區的年份列中的最小值。 然後，從2012年贏得第一枚獎牌的所有國家開始，按降序對結果進行排序。
# >
# > 有多少國家在2012年首次亮相？

# %%
summer.groupby("Country").Year.min()
# Out:
# Country
# AFG    2008
# AHO    1988
# ALG    1984
# ANZ    1908
# ARG    1924
# ARM    1996
# AUS    1896
# AUT    1896
# AZE    1996
# BAH    1956
# BAR    2000
# BDI    1996
# BEL    1900
# BER    1976
# BLR    1996
# BOH    1900
# BOT    2012
# BRA    1920
# BRN    2012
# BUL    1952
# BWI    1960
# CAN    1900
# CHI    1928
# CHN    1984
# CIV    1984
# CMR    1968
# COL    1972
# CRC    1988
# CRO    1992
# CUB    1900
#        ...
# SUD    2008
# SUI    1896
# SUR    1988
# SVK    1996
# SWE    1900
# SYR    1984
# TAN    1980
# TCH    1920
# TGA    1996
# THA    1976
# TJK    2008
# TOG    2008
# TPE    1960
# TRI    1948
# TTO    2012
# TUN    1964
# TUR    1936
# UAE    2004
# UGA    1968
# UKR    1996
# URS    1952
# URU    1924
# USA    1896
# UZB    1996
# VEN    1952
# VIE    2000
# YUG    1924
# ZAM    1984
# ZIM    1980
# ZZX    1896
# Name: Year, Length: 147, dtype: int64

# %%
summer.groupby("Country").Year.min().sort_values(ascending = False)
# 可以計算出在2012年才亮相的國家有9個。
# Out:
# Country
# MNE    2012
# SGP    2012
# BOT    2012
# BRN    2012
# CYP    2012
# GAB    2012
# GRN    2012
# GUA    2012
# TTO    2012
# AFG    2008
# TJK    2008
# TOG    2008
# MRI    2008
# SRB    2008
# SUD    2008
# UAE    2004
# PAR    2004
# ERI    2004
# SCG    2004
# MKD    2000
# KSA    2000
# BAR    2000
# KUW    2000
# KGZ    2000
# VIE    2000
# CZE    1996
# TGA    1996
# HKG    1996
# BLR    1996
# RUS    1996
#        ...
# JPN    1920
# NZL    1920
# EST    1920
# LUX    1920
# TCH    1920
# RSA    1908
# RU1    1908
# FIN    1908
# ANZ    1908
# BEL    1900
# NED    1900
# BOH    1900
# ITA    1900
# CAN    1900
# SWE    1900
# IND    1900
# NOR    1900
# CUB    1900
# ESP    1900
# FRA    1896
# HUN    1896
# GRE    1896
# DEN    1896
# AUT    1896
# AUS    1896
# GER    1896
# GBR    1896
# USA    1896
# SUI    1896
# ZZX    1896
# Name: Year, Length: 147, dtype: int64

# %% [markdown]
# ... __9__ countries!

# %% [markdown]
# ## Well Done!

# %% [markdown]
# ----------------------------------------------------------

# %% [markdown]
# ## Expert Level

# %%
import pandas as pd

# %% [markdown]
# Let´s __import summer.csv__ with the columns __"Year", "City", "Sport", "Athlete", "Country", "Gender" and "Medal"__ (parameter __usecols__!) and save the DataFrame in the variable __summer__.

# %%
summer = pd.read_csv("summer.csv", usecols = ["Year", "City", "Sport", "Athlete", "Country", "Gender", "Medal"])

# %% [markdown]
# __Inspect__ the DataFrame.

# %%
summer.head()
# Out:
#    Year    City     Sport             Athlete Country Gender   Medal
# 0  1896  Athens  Aquatics       HAJOS, Alfred     HUN    Men    Gold
# 1  1896  Athens  Aquatics    HERSCHMANN, Otto     AUT    Men  Silver
# 2  1896  Athens  Aquatics   DRIVAS, Dimitrios     GRE    Men  Bronze
# 3  1896  Athens  Aquatics  MALOKINIS, Ioannis     GRE    Men    Gold
# 4  1896  Athens  Aquatics  CHASAPIS, Spiridon     GRE    Men  Silver

# %% [markdown]
# We want to create a __new column "Medals_in_Ed"__ with the __number of Medals__ that the __respective Athlete__ won in the __respective Edition/Year__.<br>
# In a first step, __split__ summer __by "Year" and "Athlete"__ and __count__ the __number of Medals__ for each group.
# > 我們想要創建一個新的列“Medals_in_Ed”，其中包含相應運動員在相應版本/年中獲勝的獎牌數量。
# > 在第一步中，將夏季分為“年”和“運動員”，併計算每組的獎牌數量。

# %%
summer.groupby(["Year", "Athlete"]).Medal.count()
# Out:
# Year  Athlete
# 1896  ANDREOU, Joannis            1
#       ANDRIAKOPOULOS, Nicolaos    2
#       ATHANASOPOULOS, Spyros      1
#       BATTEL, Edward              1
#       BLAKE, Arthur               1
#       BOLAND, John                2
#       BURKE, Thomas               2
#       BÖCKER, Konrad              2
#       CALLOT, Henri               1
#       CHASAPIS, Spiridon          1
#       CHOROPHAS, Efstathios       2
#       CHRISTOPOULOS, Stephanos    1
#       CHRYSAPHIS, Ioannis         1
#       CLARK, Ellery               2
#       CONNOLLY, James             3
#       CURTIS, Thomas              1
#       DAMASKOS, Evangelos         1
#       DANI, Nandor                1
#       DRIVAS, Dimitrios           1
#       ELLIOTT, Launceston         2
#       FLACK, Edwin                3
#       FLAMENG, Léon               3
#       FLATOW, Alfred              4
#       FLATOW, Gustav Felix        2
#       GARRETT, Robert             4
#       GEORGIADIS, Ioannis         1
#       GMELIN, Charles             1
#       GOEDRICH, August            1
#       GOLEMIS, Dimitrios          1
#       GOULDING, Grantley          1
#                                  ..
# 2012  YONEMITSU, Tatsuhiro        1
#       YOSHIDA, Saori              1
#       YU, Dan                     1
#       YUMOTO, Shinichi            1
#       YUN, Sukyoung               1
#       ZABELINSKAYA, Olga          2
#       ZAGAME, Nicola              1
#       ZAKHAROV, Ilya              2
#       ZAKRISSON, Mattias          1
#       ZALOMIR, Florin             1
#       ZAMKOVOY, Andrey            1
#       ZANINOVIC, Lucija           1
#       ZAYTSEV, Ivan               1
#       ZELLER, Christopher         1
#       ZELLER, Philipp             1
#       ZHANG, Chenglong            1
#       ZHANG, Jike                 2
#       ZHANG, Nan                  1
#       ZHANG, Wenxiu               1
#       ZHANG, Yanquan              1
#       ZHAO, Yunlei                2
#       ZHOU, Lulu                  1
#       ZIELINSKI, Adrian Edward    1
#       ZLATIC, Andrija             1
#       ZOLNIR, Urska               1
#       ZONDERLAND, Epke            1
#       ZOU, Kai                    3
#       ZOU, Shiming                1
#       ZUEVA, Anastasia            1
#       ZURRER, Emily Jane          1
# Name: Medal, Length: 27757, dtype: int64

# %% [markdown]
# Now, __instead__ of using the the __count() method directly__ on our Groupby Object, let´s __pass "count"__ as an argument for the __transform()__ method. <br>
# By doing so, we are creating a __new Pandas Series__ which we then add as __new column "Medals_in_Ed"__ to our Dataframe. <br><br>
# __Fill in the gap!__
# > 在，不要直接在我們的Groupby對像上使用count（）方法，而是將“count”作為transform（）方法的參數傳遞。
# > 過這樣做，我們正在創建一個新的Pandas系列，然後我們將新的列“Medals_in_Ed”添加到我們的Dataframe中。
#
# > 滿空隙！

# %%
summer.groupby(["Year", "Athlete"]).Medal.transform("count")
# Out:
# 0        2
# 1        1
# 2        1
# 3        1
# 4        1
# 5        2
# 6        2
# 7        1
# 8        2
# 9        1
# 10       1
# 11       1
# 12       1
# 13       2
# 14       4
# 15       1
# 16       1
# 17       1
# 18       3
# 19       1
# 20       1
# 21       2
# 22       1
# 23       1
# 24       3
# 25       1
# 26       2
# 27       4
# 28       1
# 29       2
#         ..
# 31135    1
# 31136    1
# 31137    1
# 31138    1
# 31139    1
# 31140    1
# 31141    1
# 31142    1
# 31143    1
# 31144    1
# 31145    1
# 31146    1
# 31147    1
# 31148    1
# 31149    1
# 31150    1
# 31151    1
# 31152    1
# 31153    1
# 31154    1
# 31155    1
# 31156    1
# 31157    1
# 31158    1
# 31159    1
# 31160    1
# 31161    1
# 31162    1
# 31163    1
# 31164    1
# Name: Medal, Length: 31165, dtype: int64

# %%
# summer["Medals_in_Ed"] = ---
summer["Medals_in_Ed"] = summer.groupby(["Year", "Athlete"]).Medal.transform("count")

# %% [markdown]
# __Inspect__ the summer Dataframe with the additional column.

# %%
summer.head()
# Out:
#    Year    City     Sport             Athlete Country Gender   Medal  \
# 0  1896  Athens  Aquatics       HAJOS, Alfred     HUN    Men    Gold
# 1  1896  Athens  Aquatics    HERSCHMANN, Otto     AUT    Men  Silver
# 2  1896  Athens  Aquatics   DRIVAS, Dimitrios     GRE    Men  Bronze
# 3  1896  Athens  Aquatics  MALOKINIS, Ioannis     GRE    Men    Gold
# 4  1896  Athens  Aquatics  CHASAPIS, Spiridon     GRE    Men  Silver
#
#    Medals_in_Ed
# 0             2
# 1             1
# 2             1
# 3             1
# 4             1

# %% [markdown]
# Now, we want to know for each __combination of Year and Gender__ (e.g. 1904 Men), the __maximum number of medals__.<br>
# For example, the __most successful Men in the Edition 1904 won 6 Medals__ and the __most successful Women in 1904 won 3 Medals__, and so on...<br><br>
# How many Medals did the most successful male Athlete and female Athlete win in the Edition 2012?
# > 現在，我們想知道年度和性別的每個組合（例如1904名男子），獎牌的最大數量。
# > 例如，1904年版中最成功的男性獲得了6枚獎牌，1904年最成功的女性獲得了3枚獎牌，依此類推......
# >
# > 在2012年版中，最成功的男運動員和女運動員獲得了多少枚獎牌？

# %%
# summer.groupby(["Year", "Gender"]).Medal.count()
# 上面那一行是看 該年度, 每個性別 得到的總獎牌數量
# 
# 下面計算 該年度, 該性別中 得到最多獎牌的數量
# 拉到最下面就可以看到 2012年的男性運動員，最多得到6面獎牌；2012年女性運動員，最多得到5面獎牌
# summer.groupby(["Year", "Gender"]).Medals_in_Ed.max()
# 
# 如果不想要拉到最後，可以用sort_index()
# 注意因為是 MultiIndex，所以用index排序就會多個index都排序!!
# sort_index的參數level，則可以指定要先從哪一個參數開始排序
# 如果多個欄位的排序大到小或小到大不同，則用list指定。
summer.groupby(["Year", "Gender"]).Medals_in_Ed.max().sort_index(level = [0,1], ascending = [False, True])
# Out:
# Year  Gender
# 2012  Men       6
#       Women     5
# 2008  Men       8
#       Women     6
# 2004  Men       8
#       Women     5
# 2000  Men       6
#       Women     5
# 1996  Men       6
#       Women     4
# 1992  Men       6
#       Women     5
# 1988  Men       7
#       Women     6
# 1984  Men       6
#       Women     5
# 1980  Men       8
#       Women     5
# 1976  Men       7
#       Women     5
# 1972  Men       7
#       Women     5
# 1968  Men       7
#       Women     6
# 1964  Men       4
#       Women     6
# 1960  Men       7
#       Women     6
# 1956  Men       5
#       Women     6
# 1952  Men       6
#       Women     7
# 1948  Men       5
#       Women     4
# 1936  Men       6
#       Women     4
# 1932  Men       4
#       Women     3
# 1928  Men       4
#       Women     3
# 1924  Men       6
#       Women     3
# 1920  Men       7
#       Women     3
# 1912  Men       5
#       Women     2
# 1908  Men       3
#       Women     2
# 1904  Men       6
#       Women     3
# 1900  Men       5
#       Women     2
# 1896  Men       6
# Name: Medals_in_Ed, dtype: int64

# %% [markdown]
# ...<br>
# Best Man in 2012: 6 Medals <br>
# Best Woman in 2012: 5 Medals

# %% [markdown]
# Last but not least, we want to know for __each combination of Year and Gender__ the __three most successful athletes__ by __name, Country and Sport__.<br><br>
# The user-defined Function __best_athletes()__ has already been defined. Simply __run__ the cell!

# %%
def best_athletes(group):
    return group[["City", "Athlete", "Country", "Sport", "Medals_in_Ed"]].drop_duplicates("Athlete").nlargest(3, columns = "Medals_in_Ed" )

# %% [markdown]
# - drop_duplicate()函式，是對DataFrame格式的數據，去除特定欄位下面的重複列。

# %% [markdown]
# ---
# __Apply best_athletes__ on the appropriate Groupby object! <br>
#
# Who was the __second most successful male__ Athlete in 2012?

# %%
# 注意apply()函式裡面，input參數的函式名，不需要""。
summer.groupby(["Year", "Gender"]).apply(best_athletes)
# Out:
#                         City                        Athlete Country  \
# Year Gender
# 1896 Men    72        Athens           WEINGÄRTNER, Hermann     GER
#             14        Athens                 HOFMANN, Fritz     GER
#             27        Athens                GARRETT, Robert     USA
# 1900 Men    232        Paris      TEWKSBURY, Walter B. John     USA
#             280        Paris                 BAXTER, Irving     USA
#             230        Paris                ROWLEY, Stanley     AUS
#      Women  639        Paris                  JONES, Marion     ZZX
#             640        Paris              ROSENBAUM, Hedwig     ZZX
#             641        Paris              COOPER, Charlotte     GBR
# 1904 Men    839     St Louis                DOWNING, Burton     USA
#             964     St Louis                   HEIDA, Anton     USA
#             965     St Louis                  EYSER, George     USA
#      Women  709     St Louis                POLLOCK, Jessie     USA
#             710     St Louis          HOWELL, Matilda Scott     USA
#             711     St Louis                 COOKE, Emma C.     USA
# 1908 Men    1147      London                  TAYLOR, Henry     GBR
#             1200      London               SHEPPARD, Melvin     USA
#             1243      London               SHERIDAN, Martin     USA
#      Women  1843      London                SYERS, Florence     GBR
#             1184      London  HILL-LOWE, Beatrice Geraldine     GBR
#             1185      London    NEWALL, Sybil Fenton Quenni     GBR
# 1912 Men    2638   Stockholm           CARLBERG, G. Vilhelm     SWE
#             2016   Stockholm            KOLEHMAINEN, Hannes     FIN
#             2629   Stockholm        VON HOLST, Johan Hübner     SWE
#      Women  1955   Stockholm               FLETCHER, Jennie     GBR
#             2770   Stockholm          BROQUEDIS, Marguerite     FRA
#             2771   Stockholm                   KÖRING, Dora     GER
# 1920 Men    3838     Antwerp                    LEE, Willis     USA
#             3841     Antwerp         SPOONER, Lloyd Spencer     USA
#             2949     Antwerp              VAN INNIS, Hubert     BEL
# ...                      ...                            ...     ...
# 1996 Men    22320    Atlanta                  NEMOV, Alexei     RUS
#             21333    Atlanta               POPOV, Alexander     RUS
#             21334    Atlanta                 HALL, Gary Jr.     USA
#      Women  21329    Atlanta                 MARTINO, Angel     USA
#             21330    Atlanta                 VAN DYKEN, Amy     USA
#             21356    Atlanta          SMITH, Michelle Marie     IRL
# 2000 Men    24297     Sydney                  NEMOV, Alexei     RUS
#             23245     Sydney                    THORPE, Ian     AUS
#             23161     Sydney                 SAUTIN, Dmitry     RUS
#      Women  23212     Sydney                   TORRES, Dara     USA
#             23213     Sydney                DE BRUIJN, Inge     NED
#             23218     Sydney                THOMPSON, Jenny     USA
# 2004 Men    25225     Athens                PHELPS, Michael     USA
#             25230     Athens                    THORPE, Ian     AUS
#             25213     Athens                 PEIRSOL, Aaron     USA
#      Women  25216     Athens              COUGHLIN, Natalie     USA
#             25227     Athens                DE BRUIJN, Inge     NED
#             25228     Athens                 THOMAS, Petria     AUS
# 2008 Men    27224    Beijing                PHELPS, Michael     USA
#             27240    Beijing                   LOCHTE, Ryan     USA
#             27212    Beijing                 PEIRSOL, Aaron     USA
#      Women  27215    Beijing              COUGHLIN, Natalie     USA
#             28306    Beijing                 LIUKIN, Nastia     USA
#             27216    Beijing               COVENTRY, Kirsty     ZIM
# 2012 Men    29270     London                PHELPS, Michael     USA
#             29287     London                   LOCHTE, Ryan     USA
#             29282     London                      SUN, Yang     CHN
#      Women  29261     London                FRANKLIN, Missy     USA
#             29275     London                 COUTTS, Alicia     AUS
#             29306     London               SCHMITT, Allison     USA
#
#                         Sport  Medals_in_Ed
# Year Gender
# 1896 Men    72     Gymnastics             6
#             14      Athletics             4
#             27      Athletics             4
# 1900 Men    232     Athletics             5
#             280     Athletics             5
#             230     Athletics             4
#      Women  639        Tennis             2
#             640        Tennis             2
#             641        Tennis             2
# 1904 Men    839       Cycling             6
#             964    Gymnastics             6
#             965    Gymnastics             6
#      Women  709       Archery             3
#             710       Archery             3
#             711       Archery             3
# 1908 Men    1147     Aquatics             3
#             1200    Athletics             3
#             1243    Athletics             3
#      Women  1843      Skating             2
#             1184      Archery             1
#             1185      Archery             1
# 1912 Men    2638     Shooting             5
#             2016    Athletics             4
#             2629     Shooting             4
#      Women  1955     Aquatics             2
#             2770       Tennis             2
#             2771       Tennis             2
# 1920 Men    3838     Shooting             7
#             3841     Shooting             7
#             2949      Archery             6
# ...                       ...           ...
# 1996 Men    22320  Gymnastics             6
#             21333    Aquatics             4
#             21334    Aquatics             4
#      Women  21329    Aquatics             4
#             21330    Aquatics             4
#             21356    Aquatics             4
# 2000 Men    24297  Gymnastics             6
#             23245    Aquatics             5
#             23161    Aquatics             4
#      Women  23212    Aquatics             5
#             23213    Aquatics             4
#             23218    Aquatics             4
# 2004 Men    25225    Aquatics             8
#             25230    Aquatics             4
#             25213    Aquatics             3
#      Women  25216    Aquatics             5
#             25227    Aquatics             4
#             25228    Aquatics             4
# 2008 Men    27224    Aquatics             8
#             27240    Aquatics             4
#             27212    Aquatics             3
#      Women  27215    Aquatics             6
#             28306  Gymnastics             5
#             27216    Aquatics             4
# 2012 Men    29270    Aquatics             6
#             29287    Aquatics             5
#             29282    Aquatics             4
#      Women  29261    Aquatics             5
#             29275    Aquatics             5
#             29306    Aquatics             5
#
# [159 rows x 5 columns]

# %%
summer.groupby(["Year", "Gender"]).apply(best_athletes).sort_index(level = [0,1], ascending = [False, True]).head(10)
# Out:
#                       City            Athlete Country     Sport  Medals_in_Ed
# Year Gender
# 2012 Men    29270   London    PHELPS, Michael     USA  Aquatics             6
#             29287   London       LOCHTE, Ryan     USA  Aquatics             5
#             29282   London          SUN, Yang     CHN  Aquatics             4
#      Women  29261   London    FRANKLIN, Missy     USA  Aquatics             5
#             29275   London     COUTTS, Alicia     AUS  Aquatics             5
#             29306   London   SCHMITT, Allison     USA  Aquatics             5
# 2008 Men    27224  Beijing    PHELPS, Michael     USA  Aquatics             8
#             27240  Beijing       LOCHTE, Ryan     USA  Aquatics             4
#             27212  Beijing     PEIRSOL, Aaron     USA  Aquatics             3
#      Women  27215  Beijing  COUGHLIN, Natalie     USA  Aquatics             6

# %% [markdown]
# ... it was ... Ryan Lochte (USA) with 5 Medals in Aquatics.

# %% [markdown]
# ## Well Done! Looking forward to seeing you in the BONUS Section!
