# %% [markdown]
# # Pandas Basic
# ## Data import and First Inspection(檢查)
#
# tabular data 表格式的資料

# %% [markdown]
# ---
# ## 載入套件

# %%
import pandas as pd

# %% [markdown]
# ---
# ## 讀取資料
# - 注意路徑會從目前此.ipynb檔的位置開始
#
#
# - 讀取資料，最下面會顯示rows數與columns數
# - 注意index是從0開始
#
# - 資料來源: https://github.com/fsharp/FSharp.Data/blob/master/docs/content/data/Titanic.csv
# - 我有用R稍微先整理過~

# %%
pd.read_csv("../data/titanic_ver01.csv")
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Fare  \
# 0              1         0       3    male  22.0      1      0    7.2500
# 1              2         1       1  female  38.0      1      0   71.2833
# 2              3         1       3  female  26.0      0      0    7.9250
# 3              4         1       1  female  35.0      1      0   53.1000
# 4              5         0       3    male  35.0      0      0    8.0500
# 5              6         0       3    male   NaN      0      0    8.4583
# 6              7         0       1    male  54.0      0      0   51.8625
# 7              8         0       3    male   2.0      3      1   21.0750
# 8              9         1       3  female  27.0      0      2   11.1333
# 9             10         1       2  female  14.0      1      0   30.0708
# 10            11         1       3  female   4.0      1      1   16.7000
# 11            12         1       1  female  58.0      0      0   26.5500
# ...

# %%
titanic = pd.read_csv("../data/titanic_ver01.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Fare  \
# 0              1         0       3    male  22.0      1      0    7.2500
# 1              2         1       1  female  38.0      1      0   71.2833
# 2              3         1       3  female  26.0      0      0    7.9250
# 3              4         1       1  female  35.0      1      0   53.1000
# 4              5         0       3    male  35.0      0      0    8.0500
# 5              6         0       3    male   NaN      0      0    8.4583
# 6              7         0       1    male  54.0      0      0   51.8625
# 7              8         0       3    male   2.0      3      1   21.0750
# 8              9         1       3  female  27.0      0      2   11.1333
# 9             10         1       2  female  14.0      1      0   30.0708
# 10            11         1       3  female   4.0      1      1   16.7000
# 11            12         1       1  female  58.0      0      0   26.5500
# ...

# %% [markdown]
# - 通常我們只會看前幾筆
# - 顯示前五筆
# - 按shift+tab，可以看到完整的參數設定

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
#
#   Embarked Cabin
# 0        S   NaN
# 1        C     C
# 2        S   NaN
# 3        S     C
# 4        S   NaN

# %%
titanic.head(n=10)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
# 5            6         0       3    male   NaN      0      0   8.4583
# 6            7         0       1    male  54.0      0      0  51.8625
# 7            8         0       3    male   2.0      3      1  21.0750
# 8            9         1       3  female  27.0      0      2  11.1333
# 9           10         1       2  female  14.0      1      0  30.0708
#
#   Embarked Cabin
# 0        S   NaN
# 1        C     C
# 2        S   NaN
# 3        S     C
# 4        S   NaN
# 5        Q   NaN
# 6        S     E
# 7        S   NaN
# 8        S   NaN
# ...

# %% [markdown]
# - 看後五筆

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch   Fare  \
# 886          887         0       2    male  27.0      0      0  13.00
# 887          888         1       1  female  19.0      0      0  30.00
# 888          889         0       3  female   NaN      1      2  23.45
# 889          890         1       1    male  26.0      0      0  30.00
# 890          891         0       3    male  32.0      0      0   7.75
#
#     Embarked Cabin
# 886        S   NaN
# 887        S     B
# 888        S   NaN
# 889        C     C
# 890        Q   NaN

# %%
titanic.tail(n=3)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch   Fare  \
# 888          889         0       3  female   NaN      1      2  23.45
# 889          890         1       1    male  26.0      0      0  30.00
# 890          891         0       3    male  32.0      0      0   7.75
#
#     Embarked Cabin
# 888        S   NaN
# 889        C     C
# 890        Q   NaN

# %% [markdown]
# ---
# -  觀看資料的型態(data type)
# -  可以看到目前是一個pandas dataframe

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
# 沒有括弧的話，會顯示raw data的樣子
titanic.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Fare  \
# 0              1         0       3    male  22.0      1      0    7.2500
# 1              2         1       1  female  38.0      1      0   71.2833
# 2              3         1       3  female  26.0      0      0    7.9250
# 3              4         1       1  female  35.0      1      0   53.1000
# 4              5         0       3    male  35.0      0      0    8.0500
# 5              6         0       3    male   NaN      0      0    8.4583
# 6              7         0       1    male  54.0      0      0   51.8625
# 7              8         0       3    male   2.0      3      1   21.0750
# 8              9         1       3  female  27.0      0      2   11.1333
# 9             10         1       2  female  14.0      1      0   30.0708
# 10            11         1       3  female   4.0      1      1   16.7000
# ...

# %% [markdown]
# - 從這邊可以看到
#     - 那些欄位有缺失值，以及缺失值的個數
#     - 一共有幾欄
#     - 該欄位變數紀錄的數值型態
# - object就類似character、string
# - 最下面還有寫佔用了多少記憶體
# - print(titanic.info()) 效果相同

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Fare           891 non-null float64
# Embarked       889 non-null object
# Cabin          204 non-null object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# - 觀看欄位有哪些
# - Cabin = deck 船艙

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Fare', 'Embarked', 'Cabin'],
#       dtype='object')

# %% [markdown]
# - 觀看index

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %% [markdown]
# - 快速看一下data的variable summary，有各種不同的attribute
# - <font color = "red">而且平均的分母是依照該欄位有值的空格有幾個，而不是都除以891</font>
# - 從第一列的count也可以知道那些欄位有多少缺失值。

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# - 想特別觀看哪一個attribute

# %%
titanic.mean()
# titanic.max()
# titanic.min() #類別型的欄位也可以看min，就像True, False個別有值一樣~
# titanic.std()
# 
# 25百分位數。另外有一個參數interpolation = {‘linear’, ‘lower’, ‘higher’, ‘midpoint’, ‘nearest’}，可以深入研究。
# 只有計算數值欄位，包括int, float型態。
# titanic.quantile(q=0.25)
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %% [markdown]
# ---
# ## 另一個資料集

# %% [markdown]
# ---
#
# 接下來用的的summer.csv
# 是奧民匹克運動會的數據資料
# 來源: https://www.kaggle.com/shreyasp1/gender-by-year-for-summer

# %%
# Discipline: 學科
pd.read_csv("../data/summer.csv")
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# 5      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 7      1896  Athens   Aquatics             Swimming
# 8      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 10     1896  Athens   Aquatics             Swimming
# 11     1896  Athens  Athletics            Athletics
# 12     1896  Athens  Athletics            Athletics
# 13     1896  Athens  Athletics            Athletics
# 14     1896  Athens  Athletics            Athletics
# 15     1896  Athens  Athletics            Athletics
# 16     1896  Athens  Athletics            Athletics
# ...

# %%
summer = pd.read_csv("../data/summer.csv")

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer.tail()
# Out:
#        Year    City      Sport           Discipline  \
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender     Event   Medal
# 31160         JANIKOWSKI, Damian     POL    Men  Wg 84 KG  Bronze
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men  Wg 96 KG    Gold
# 31162             TOTROV, Rustam     RUS    Men  Wg 96 KG  Silver
# 31163          ALEKSANYAN, Artur     ARM    Men  Wg 96 KG  Bronze
# 31164             LIDBERG, Jimmy     SWE    Men  Wg 96 KG  Bronze

# %% [markdown]
# - 可以看到總共有多少rows = 31165
# - 可以看到只有Country有missing value
# - 然後幾乎的是object型態，即為string

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
# Year          31165 non-null int64
# City          31165 non-null object
# Sport         31165 non-null object
# Discipline    31165 non-null object
# Athlete       31165 non-null object
# Country       31161 non-null object
# Gender        31165 non-null object
# Event         31165 non-null object
# Medal         31165 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB
